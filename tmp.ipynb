# %%
import nibabel as nib

nii = nib.load("/mnt/gpussd2/jrich/Desktop/ADPKD/crisp/T2_HASTE/2125/1_002125_1004/1004_WET-KID-PK-PROTOCOL_HASTE_000000_4.nii.gz")
print(nii.header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 54
# dim             : [  3 256 256  22   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.000000e+00  1.367188e+00  1.367188e+00  9.000004e+00  4.400000e-03
#   0.000000e+00  0.000000e+00  0.000000e+00]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'TE=90;Time=0.000;mb=22'
# aux_file        : b''
# qform_code      : scanner
# sform_code      : scanner
# ...
